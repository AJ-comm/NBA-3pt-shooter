# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import leagueleaders
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline

import pandas as pd

# %%
player_stats = leagueleaders.LeagueLeaders(
  
   season='2021-22',
   season_type_all_star='Regular Season',
   stat_category_abbreviation='PTS'
).get_data_frames()[0][:500]

pd.set_option('display.max_columns', None)
player_stats
# Out:
#      PLAYER_ID  RANK                  PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0      1629027     1              Trae Young  1610612737  ATL  76  2652  711
# 1       201942     2           DeMar DeRozan  1610612741  CHI  76  2743  774
# 2       203954     3             Joel Embiid  1610612755  PHI  68  2296  666
# 3      1628369     4            Jayson Tatum  1610612738  BOS  76  2731  708
# 4       203999     5            Nikola Jokic  1610612743  DEN  74  2476  764
# ..         ...   ...                     ...         ...  ...  ..   ...  ...
# 495    1629683   493  Quinndary Weatherspoon  1610612744  GSW  11    73   12
# 496    1629653   497            Devon Dotson  1610612741  CHI  11    85   11
# 497     203516   497         James Ennis III  1610612743  DEN   7    56   11
# 498     202334   499                Ed Davis  1610612739  CLE  31   201   11
# 499    1630222   500             Mason Jones  1610612747  LAL   4    51    7
#
#       FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB   REB  \
# 0    1544   0.460   233   610    0.382  500  553   0.904    50   234   284
# 1    1535   0.504    50   142    0.352  520  593   0.877    56   336   392
# 2    1334   0.499    93   251    0.371  654  803   0.814   146   650   796
# 3    1564   0.453   230   651    0.353  400  469   0.853    85   524   609
# 4    1311   0.583    97   288    0.337  379  468   0.810   206   813  1019
# ..    ...     ...   ...   ...      ...  ...  ...     ...   ...   ...   ...
# 495    21   0.571     1     5    0.200    5    5   1.000     2    12    14
# 496    23   0.478     2     9    0.222    5    9   0.556     1     8     9
# 497    24   0.458     3     8    0.375    4    5   0.800     5     7    12
# 498    16   0.688     0     0    0.000    6   14   0.429    14    50    64
# 499    15   0.467     1     4    0.250   12   15   0.800     1     9    10
#
#      AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  STL_TOV
# 0    737   72    7  303  128  2155  2066     2.43     0.24
# 1    374   68   24  181  178  2118  1961     2.07     0.38
# 2    284   77   99  214  181  2079  2304     1.33     0.36
# 3    334   75   49  217  174  2046  1971     1.54     0.35
# 4    584  109   63  281  191  2004  2862     2.08     0.39
# ..   ...  ...  ...  ...  ...   ...   ...      ...      ...
# 495    5    1    1    3   15    30    39     1.67     0.33
# 496   15    1    0    5   11    29    33     3.00     0.20
# 497    3    2    2    2    5    29    32     1.50     1.00
# 498    7    3    9    5   33    28    93     1.40     0.60
# 499    4    2    0    1    8    27    31     4.00     2.00
#
# [500 rows x 28 columns]

# %%
# Assuming player_stats is your DataFrame
selected_columns = ['PLAYER', 'TEAM', 'GP', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'PTS', 'EFF']
filtered_player_stats = player_stats[selected_columns]
filtered_player_stats.set_index('PLAYER', inplace=True)
# Display the filtered DataFrame
filtered_player_stats
# Out:
#                        TEAM  GP  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT   PTS  \
# PLAYER
# Trae Young              ATL  76  711  1544   0.460   233   610    0.382  2155
# DeMar DeRozan           CHI  76  774  1535   0.504    50   142    0.352  2118
# Joel Embiid             PHI  68  666  1334   0.499    93   251    0.371  2079
# Jayson Tatum            BOS  76  708  1564   0.453   230   651    0.353  2046
# Nikola Jokic            DEN  74  764  1311   0.583    97   288    0.337  2004
# ...                     ...  ..  ...   ...     ...   ...   ...      ...   ...
# Quinndary Weatherspoon  GSW  11   12    21   0.571     1     5    0.200    30
# Devon Dotson            CHI  11   11    23   0.478     2     9    0.222    29
# James Ennis III         DEN   7   11    24   0.458     3     8    0.375    29
# Ed Davis                CLE  31   11    16   0.688     0     0    0.000    28
# Mason Jones             LAL   4    7    15   0.467     1     4    0.250    27
#
#                          EFF
# PLAYER
# Trae Young              2066
# DeMar DeRozan           1961
# Joel Embiid             2304
# Jayson Tatum            1971
# Nikola Jokic            2862
# ...                      ...
# Quinndary Weatherspoon    39
# Devon Dotson              33
# James Ennis III           32
# Ed Davis                  93
# Mason Jones               31
#
# [500 rows x 10 columns]

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('all_seasons.csv')

# Select specific columns from the DataFrame
selected_columns = ['player_name', 'player_height', 'player_weight']
filtered_df = df[selected_columns]

# Display the filtered DataFrame
filtered_df
# Out:
#             player_name  player_height  player_weight
# 0      Randy Livingston         193.04      94.800728
# 1      Gaylon Nickerson         190.50      86.182480
# 2          George Lynch         203.20     103.418976
# 3        George McCloud         203.20     102.058200
# 4          George Zidek         213.36     119.748288
# ...                 ...            ...            ...
# 12839       Joel Embiid         213.36     127.005760
# 12840   John Butler Jr.         213.36      86.182480
# 12841      John Collins         205.74     102.511792
# 12842      Jericho Sims         208.28     113.398000
# 12843    JaMychal Green         205.74     102.965384
#
# [12844 rows x 3 columns]

# %%
# Assuming player_stats is your DataFrame
selected_columns_player_stats = ['PLAYER', 'TEAM', 'GP', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'PTS', 'EFF']
filtered_player_stats = player_stats[selected_columns_player_stats]
filtered_player_stats.set_index('PLAYER', inplace=True)

# Read the CSV file into a DataFrame
df = pd.read_csv('all_seasons.csv')

# Select specific columns from the DataFrame
selected_columns_filtered_df = ['player_name', 'player_height', 'player_weight']
filtered_df = df[selected_columns_filtered_df]

# Strip whitespaces
filtered_player_stats.index = filtered_player_stats.index.str.strip()
filtered_df['player_name'] = filtered_df['player_name'].str.strip()

# Remove duplicates from filtered_df based on 'player_name'
filtered_df = filtered_df.drop_duplicates(subset=['player_name'])

# Merge the DataFrames on the 'PLAYER' and 'player_name' columns
combined_df = pd.merge(filtered_player_stats,filtered_df, left_index=True, right_on='player_name', how='inner')
combined_df.set_index('player_name', inplace=True)
combined_df.head(50)
# Out:
# /var/folders/x6/szcht9hj5l98b_p2wh6znbb80000gn/T/ipykernel_67392/2537108273.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['player_name'] = filtered_df['player_name'].str.strip()
#                         TEAM  GP  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
